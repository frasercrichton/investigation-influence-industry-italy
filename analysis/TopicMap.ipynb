# %% [markdown]
# # Topic Map

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re

docs = []
def parse_text(file_location): 
    transcriptions_df = pd.read_json(file_location)
    transcription_text = transcriptions_df[0].iloc[0] 
    sentence_list = re.split('(\.)', transcription_text)
    result = []
    if len(sentence_list) > 0: 
        for sentence in sentence_list:   
          if sentence == '.':
            result.append('. ')
          else:    
            result.append(sentence)
    else:
        print('No fullstops')
        result.append(transcription_text)

    docs.append(transcriptions_df[0].iloc[0])

for file_name in os.listdir(transcription_dir_location_en):
    parse_text(transcription_dir_location_en + file_name)



docs

# docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
# docs
docs = list(filter(None, docs))


from bertopic.vectorizers import ClassTfidfTransformer

# ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
# topic_model = BERTopic(ctfidf_model=ctfidf_model, nr_topics=20)

# vectorizer_model = CountVectorizer(max_df=0.95, min_df=2, max_features=10, stop_words=['english'])
# topic_model = BERTopic(vectorizer_model=vectorizer_model) 
# , min_topic_size=1

# from hdbscan import HDBSCAN

# hdbscan_model = HDBSCAN(min_cluster_size=10, metric='euclidean', 
#                         cluster_selection_method='eom', prediction_data=True, min_samples=5)
# topic_model = BERTopic(hdbscan_model=hdbscan_model, min_topic_size=2, nr_topics=5)

topics, probs = topic_model.fit_transform(docs)

# ##########################

# from bertopic.representation import KeyBERTInspired
# from bertopic import BERTopic

# # Create your representation model
# representation_model = KeyBERTInspired()

# # Use the representation model in BERTopic on top of the default pipeline
# topic_model = BERTopic(representation_model=representation_model)

################################
from bertopic.representation import PartOfSpeech
from bertopic import BERTopic

# Create your representation model
representation_model = PartOfSpeech("en_core_web_sm")

# Use the representation model in BERTopic on top of the default pipeline
topic_model = BERTopic(representation_model=representation_model)

# topic_model.update_topics(docs, topics, n_gram_range=(1, 3))

# new_topics = list(np.argmax(probs, axis=1)[1:])

# topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# docs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/frasercrichton/Development/investigation-influence-industry-italy/analysis/TopicMap.ipynb Cell 2 line 6
#      <a href='vscode-notebook-cell:/Users/frasercrichton/Development/investigation-influence-industry-italy/analysis/TopicMap.ipynb#W1sZmlsZQ%3D%3D?line=63'>64</a> from bertopic import BERTopic
#      <a href='vscode-notebook-cell:/Users/frasercrichton/Development/investigation-influence-industry-italy/analysis/TopicMap.ipynb#W1sZmlsZQ%3D%3D?line=65'>66</a> # Create your representation model
# ---> <a href='vscode-notebook-cell:/Users/frasercrichton/Development/investigation-influence-industry-italy/analysis/TopicMap.ipynb#W1sZmlsZQ%3D%3D?line=66'>67</a> representation_model = PartOfSpeech("en_core_web_sm")
# ...

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                  Name  \
# 0     -1     29  -1_italian_italy_government_economic
# 1      0     83     0_italian_italy_government_nation
# 2      1     67    1_income_government_italy_citizens
#
#                                       Representation  \
# 0  [italian, italy, government, economic, europe,...
# 1  [italian, italy, government, nation, much, eur...
# 2  [income, government, italy, citizens, tax, wor...
#
#                                  Representative_Docs
# 0  [and as I was saying, Italy shares the objecti...
# 1  [mhm. In other words, if we have to laugh, let...
# 2  [the situation is very complex and there are v...

# %%
topic_model.get_topic(1)
# Out:
# [('wages', 0.36262006),
#  ('income', 0.32903445),
#  ('wage', 0.31388998),
#  ('taxes', 0.2923096),
#  ('tax', 0.27444032),
#  ('italy', 0.27266774),
#  ('government', 0.23782288),
#  ('euros', 0.20893386),
#  ('money', 0.19852853),
#  ('cash', 0.18307385)]

# %%
topic_model.get_document_info(docs)
# Out:
#                                               Document  Topic  \
# 0    Another important chapter of our work in recen...      2
# 1    This year marks the tenth anniversary of the f...      0
# 2    one hundred days after the inauguration of the...      2
# 3    it would have been easy in this election campa...     -1
# 4    it is a maneuver resulting from political choi...      1
# ..                                                 ...    ...
# 174  Getting around our cities is becoming more dif...      2
# 175  we also have the dispute. Hurray! So at least ...     -1
# 176                                         Thanks but     -1
# 177  we are not satisfied with the outcome of these...      0
# 178  and even more I think we must be satisfied wit...      2
#
#                                      Name  \
# 0     2_italian_italy_citizens_government
# 1    0_italian_italy_political_government
# 2     2_italian_italy_citizens_government
# 3      -1_italy_europe_government_italian
# ...

# %%
topic_model.visualize_topics()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/frasercrichton/Development/investigation-influence-industry-italy/analysis/TopicMap.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/frasercrichton/Development/investigation-influence-industry-italy/analysis/TopicMap.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> topic_model.visualize_topics()
#
# File ~/Development/data-investigation-conspiracy-aotearoa/conda-env/investigation-influence-industry/lib/python3.11/site-packages/bertopic/_bertopic.py:2193, in BERTopic.visualize_topics(self, topics, top_n_topics, custom_labels, title, width, height)
#    2163 """ Visualize topics, their sizes, and their corresponding words
#    2164
#    2165 This visualization is highly inspired by LDAvis, a great visualization
#    (...)
#    2190 ```
#    2191 """
#    2192 check_is_fitted(self)
# ...
